# %% [markdown]
# # User overview Analysis

# %% [markdown]
# Data Cleaning makes the data ready for modelling and analysis.

# %%
# packages for path locations
import os
import sys

# %%
# package scripts in the script module folder 
sys.path.insert(0,'../scripts/')

# %%
#importing the some libraries for the project
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from statistics import *
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the data excel sheet
df=pd.read_csv('../data/Week1_challenge_data_source(CSV).csv', na_values=['?', None])
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
# column names
df.columns.tolist()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
#  'Nb of sec with Vol DL < 6250B',
#  'Nb of sec with Vol UL < 1250B',
#  'Social Media DL (Bytes)',
#  'Social Media UL (Bytes)',
#  'Google DL (Bytes)',
#  'Google UL (Bytes)',
#  'Email DL (Bytes)',
#  'Email UL (Bytes)',
#  'Youtube DL (Bytes)',
#  'Youtube UL (Bytes)',
#  'Netflix DL (Bytes)',
#  'Netflix UL (Bytes)',
#  'Gaming DL (Bytes)',
#  'Gaming UL (Bytes)',
#  'Other DL (Bytes)',
#  'Other UL (Bytes)',
#  'Total UL (Bytes)',
#  'Total DL (Bytes)']

# %%
# number of data points
print(f" There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
#  There are 150001 rows and 55 columns

# %% [markdown]
# # Top 10 handsets used by the customers.

# %%
handsetType = df['Handset Type'].value_counts()[:10]
handsetType
# Out:
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset Type, dtype: int64

# %%
topHandsetType = df.groupby(['Handset Type']).agg({'Handset Type': ['count']})
topHandsetType.columns = ['count']
topHandsetType = topHandsetType.reset_index()
topHandsetType.head()
# Out:
#                         Handset Type  count
# 0         A-Link Telecom I. Cubot A5      1
# 1  A-Link Telecom I. Cubot Note Plus      1
# 2     A-Link Telecom I. Cubot Note S      1
# 3       A-Link Telecom I. Cubot Nova      1
# 4      A-Link Telecom I. Cubot Power      1

# %%
topHandsetType = topHandsetType.nlargest(10, 'count')
topHandsetType = topHandsetType.reset_index(drop=True)
print('############################################')
print('Top 10 handsets used by customers')
print('############################################')
topHandsetType
# Out:
# ############################################
# Top 10 handsets used by customers
# ############################################
#                    Handset Type  count
# 0              Huawei B528S-23A  19752
# 1       Apple iPhone 6S (A1688)   9419
# 2        Apple iPhone 6 (A1586)   9023
# 3                     undefined   8987
# 4        Apple iPhone 7 (A1778)   6326
# 5       Apple iPhone Se (A1723)   5187
# 6        Apple iPhone 8 (A1905)   4993
# 7       Apple iPhone Xr (A2105)   4568
# 8  Samsung Galaxy S8 (Sm-G950F)   4520
# 9        Apple iPhone X (A1901)   3813

# %%
topHandsetType.plot.bar(x='Handset Type' ,stacked=True, color='red')
# Out:
# <AxesSubplot:xlabel='Handset Type'>

# %%
topHandsetComp = df['Handset Manufacturer'].value_counts()[:3]
topHandsetComp
# Out:
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: Handset Manufacturer, dtype: int64

# %%
topHandsetManu = df.groupby(['Handset Manufacturer']).agg({'Handset Manufacturer': ['count']})
topHandsetManu.columns = ['count']
topHandsetManu = topHandsetManu.reset_index()
topHandsetManu.head()
# Out:
#                       Handset Manufacturer  count
# 0  A-Link Telecom International Co Limited      8
# 1                                  ASUSTeK     23
# 2                                     Acer     14
# 3                                     Adar      1
# 4                      Alif Communications      1

# %%
topHandsetManu = topHandsetManu.nlargest(3, 'count')
topHandsetManu = topHandsetManu.reset_index(drop=True)
print('############################################')
print('Top 3 handsets Manufacturer')
print('############################################')
topHandsetManu
# Out:
# ############################################
# Top 3 handsets Manufacturer
# ############################################
#   Handset Manufacturer  count
# 0                Apple  59565
# 1              Samsung  40839
# 2               Huawei  34423

# %%
topHandsetManu.plot.bar(x='Handset Manufacturer' , stacked=True, color='black')
# Out:
# <AxesSubplot:xlabel='Handset Manufacturer'>

# %% [markdown]
# ## Top 5 handsets per top 3 handset manufacturer

# %%
appleTop = df.loc[df['Handset Manufacturer'] == 'Apple']
appleTop = appleTop.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
appleTop.columns = ['count']
appleTop=appleTop.nlargest(5, 'count')
appleTop
# Out:
#                                               count
# Handset Manufacturer Handset Type
# Apple                Apple iPhone 6S (A1688)   9419
#                      Apple iPhone 6 (A1586)    9023
#                      Apple iPhone 7 (A1778)    6326
#                      Apple iPhone Se (A1723)   5187
#                      Apple iPhone 8 (A1905)    4993

# %%
appleTop.plot.bar(y='count', stacked=True, color='blue')
# Out:
# <AxesSubplot:xlabel='Handset Manufacturer,Handset Type'>

# %%
appleTop.plot.bar(y='count', stacked=True, color='blue')
# Out:
# <AxesSubplot:xlabel='Handset Manufacturer,Handset Type'>

# %%
samTop = df.loc[df['Handset Manufacturer'] == 'Samsung']
samTop = samTop.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
samTop.columns = ['count']
samTop=samTop.nlargest(5, 'count')
samTop
# Out:
#                                                    count
# Handset Manufacturer Handset Type
# Samsung              Samsung Galaxy S8 (Sm-G950F)   4520
#                      Samsung Galaxy A5 Sm-A520F     3724
#                      Samsung Galaxy J5 (Sm-J530)    3696
#                      Samsung Galaxy J3 (Sm-J330)    3484
#                      Samsung Galaxy S7 (Sm-G930X)   3199

# %%
samTop.plot.bar(y='count', stacked=True, color='green')
# Out:
# <AxesSubplot:xlabel='Handset Manufacturer,Handset Type'>

# %%
huwTop = df.loc[df['Handset Manufacturer'] == 'Huawei']
huwTop = huwTop.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
huwTop.columns = ['count']
huwTop=huwTop.nlargest(5, 'count')
huwTop
# Out:
#                                                      count
# Handset Manufacturer Handset Type
# Huawei               Huawei B528S-23A                19752
#                      Huawei E5180                     2079
#                      Huawei P20 Lite Huawei Nova 3E   2021
#                      Huawei P20                       1480
#                      Huawei Y6 2018                    997

# %%
huwTop.plot.bar(y='count', stacked=True, color='green')
# Out:
# <AxesSubplot:xlabel='Handset Manufacturer,Handset Type'>

# %%
top5 = df.loc[:,['Handset Type','Handset Manufacturer']]
value = top5.groupby(['Handset Manufacturer', 'Handset Type']).size()
topList = pd.Series(dtype='object')
for i in topHandsetComp.index:
    topList = topList.append(value[i])
top5List = topList.sort_values(ascending=False)[:5]

# %%
top5List
# Out:
# Huawei B528S-23A           19752
# Apple iPhone 6S (A1688)     9419
# Apple iPhone 6 (A1586)      9023
# Apple iPhone 7 (A1778)      6326
# Apple iPhone Se (A1723)     5187
# dtype: int64

# %%
top5List.plot.bar(y='count', stacked=True, color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Apple, Samsung, and Huawei phones are among the most popular on the network, accounting for 134,827 users. Hwawei B528S-23A is the most popular phone, accounting for 19752 units. Apple iPhone 6S, 6, 7, and Se are the next 4 big popular phones after Huawei. Users prefer the Huawei B528S-23A, so we know that selling more and similar Huawei phones, running promotions on their similar product will account for success in future busenesses. This also will apply to the four models of Apple

# %% [markdown]
# # Task 1.1 - Your employer wants to have an overview of the users’ behavior on those applications.

# %% [markdown]
# Aggregate per user the following information in the column number of xDR sessions
# Session duration
# the total download (DL) and upload (UL) data
# the total data volume (in Bytes) during this session for each application

# %% [markdown]
# # Data Information

# %%
import os, sys
import pandas as pd
import numpy as np
# package scripts in the script module folder 
sys.path.append(os.path.abspath(os.path.join('../../scripts')))
from data_preprocessing import data_preProcessing_script

# %%
# object of the script class
preProcess = data_preProcessing_script(df)

# %%
preProcess.show_datatypes()
# Out:
# Bearer Id                                   float64
# Start                                        object
# Start ms                                    float64
# End                                          object
# End ms                                      float64
# Dur. (ms)                                   float64
# IMSI                                        float64
# MSISDN/Number                               float64
# IMEI                                        float64
# Last Location Name                           object
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# 250 Kbps < DL TP < 1 Mbps (%)               float64
# DL TP > 1 Mbps (%)                          float64
# UL TP < 10 Kbps (%)                         float64
# 10 Kbps < UL TP < 50 Kbps (%)               float64
# 50 Kbps < UL TP < 300 Kbps (%)              float64
# UL TP > 300 Kbps (%)                        float64
# HTTP DL (Bytes)                             float64
# HTTP UL (Bytes)                             float64
# Activity Duration DL (ms)                   float64
# Activity Duration UL (ms)                   float64
# Dur. (ms).1                                 float64
# Handset Manufacturer                         object
# Handset Type                                 object
# Nb of sec with 125000B < Vol DL             float64
# Nb of sec with 1250B < Vol UL < 6250B       float64
# Nb of sec with 31250B < Vol DL < 125000B    float64
# Nb of sec with 37500B < Vol UL              float64
# Nb of sec with 6250B < Vol DL < 31250B      float64
# Nb of sec with 6250B < Vol UL < 37500B      float64
# Nb of sec with Vol DL < 6250B               float64
# Nb of sec with Vol UL < 1250B               float64
# Social Media DL (Bytes)                     float64
# Social Media UL (Bytes)                     float64
# Google DL (Bytes)                           float64
# Google UL (Bytes)                           float64
# Email DL (Bytes)                            float64
# Email UL (Bytes)                            float64
# Youtube DL (Bytes)                          float64
# Youtube UL (Bytes)                          float64
# Netflix DL (Bytes)                          float64
# Netflix UL (Bytes)                          float64
# Gaming DL (Bytes)                           float64
# Gaming UL (Bytes)                           float64
# Other DL (Bytes)                            float64
# Other UL (Bytes)                            float64
# Total UL (Bytes)                            float64
# Total DL (Bytes)                            float64
# dtype: object

# %%
#getting the summary of our dataframe, the null values
preProcess.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 62.9+ MB

# %%
preProcess.show_correlation()
# Out:
#                                           Bearer Id  Start ms    End ms  \
# Bearer Id                                  1.000000  0.002961 -0.001219
# Start ms                                   0.002961  1.000000  0.120945
# End ms                                    -0.001219  0.120945  1.000000
# Dur. (ms)                                  0.007515  0.001287 -0.001302
# IMSI                                       0.000152 -0.000054  0.000328
# MSISDN/Number                             -0.003307 -0.001021 -0.001890
# IMEI                                       0.164054 -0.001133 -0.000032
# Avg RTT DL (ms)                           -0.022561  0.004141 -0.005287
# Avg RTT UL (ms)                            0.034924 -0.002221 -0.002607
# Avg Bearer TP DL (kbps)                    0.063973 -0.000690  0.000694
# Avg Bearer TP UL (kbps)                    0.048123 -0.001268  0.000687
# TCP DL Retrans. Vol (Bytes)                0.019186  0.000328  0.004941
# TCP UL Retrans. Vol (Bytes)                0.008768 -0.003581 -0.003375
# DL TP < 50 Kbps (%)                       -0.069366  0.000720 -0.003683
# 50 Kbps < DL TP < 250 Kbps (%)             0.044336 -0.003107  0.004041
# 250 Kbps < DL TP < 1 Mbps (%)              0.062261 -0.000161  0.002347
# DL TP > 1 Mbps (%)                         0.063333  0.002657  0.002761
# UL TP < 10 Kbps (%)                       -0.041052  0.000254 -0.001993
# 10 Kbps < UL TP < 50 Kbps (%)              0.032303 -0.000158  0.002116
# 50 Kbps < UL TP < 300 Kbps (%)             0.016860  0.000389  0.002523
# UL TP > 300 Kbps (%)                       0.010717  0.000124 -0.001948
# HTTP DL (Bytes)                            0.029862  0.003431  0.003216
# HTTP UL (Bytes)                            0.030761  0.001835 -0.001732
# Activity Duration DL (ms)                  0.081538 -0.000043  0.000404
# Activity Duration UL (ms)                  0.069185 -0.000338 -0.000790
# Dur. (ms).1                                0.007515  0.001287 -0.001302
# Nb of sec with 125000B < Vol DL            0.068757  0.007230  0.002237
# Nb of sec with 1250B < Vol UL < 6250B      0.033748 -0.000899  0.000798
# Nb of sec with 31250B < Vol DL < 125000B   0.087384  0.000793  0.002715
# Nb of sec with 37500B < Vol UL             0.011416 -0.001777 -0.008467
# Nb of sec with 6250B < Vol DL < 31250B     0.083259 -0.001404  0.006226
# Nb of sec with 6250B < Vol UL < 37500B     0.015573 -0.003553 -0.000638
# Nb of sec with Vol DL < 6250B              0.083282  0.000196 -0.004367
# Nb of sec with Vol UL < 1250B              0.076741  0.002220 -0.002287
# Social Media DL (Bytes)                   -0.000845  0.001262  0.003102
# Social Media UL (Bytes)                   -0.001124  0.000385 -0.004010
# Google DL (Bytes)                         -0.000693  0.002274 -0.001284
# Google UL (Bytes)                          0.002257  0.000722  0.004191
# Email DL (Bytes)                           0.002626  0.001144 -0.002262
# Email UL (Bytes)                          -0.000328 -0.001176 -0.000538
# Youtube DL (Bytes)                        -0.002466 -0.001582 -0.003741
# Youtube UL (Bytes)                        -0.000703  0.001238 -0.003450
# Netflix DL (Bytes)                        -0.000622 -0.002593  0.004132
# Netflix UL (Bytes)                        -0.003725 -0.002334 -0.001156
# Gaming DL (Bytes)                          0.000487 -0.004229 -0.004687
# Gaming UL (Bytes)                         -0.003212 -0.002512  0.000988
# Other DL (Bytes)                           0.000943 -0.003687  0.002758
# Other UL (Bytes)                          -0.002240  0.003803  0.002786
# Total UL (Bytes)                          -0.004577 -0.000028 -0.000574
# Total DL (Bytes)                           0.000400 -0.004299 -0.004687
#
#                                           Dur. (ms)      IMSI  MSISDN/Number  \
# Bearer Id                                  0.007515  0.000152      -0.003307
# Start ms                                   0.001287 -0.000054      -0.001021
# End ms                                    -0.001302  0.000328      -0.001890
# Dur. (ms)                                  1.000000 -0.019798       0.024616
# IMSI                                      -0.019798  1.000000      -0.662558
# MSISDN/Number                              0.024616 -0.662558       1.000000
# IMEI                                      -0.058043 -0.000536       0.005703
# Avg RTT DL (ms)                           -0.052472 -0.000365      -0.001701
# Avg RTT UL (ms)                           -0.002981 -0.000437       0.008404
# Avg Bearer TP DL (kbps)                   -0.165355 -0.000557      -0.001857
# Avg Bearer TP UL (kbps)                   -0.113996 -0.000269      -0.001278
# TCP DL Retrans. Vol (Bytes)                0.018902 -0.003147       0.020756
# TCP UL Retrans. Vol (Bytes)                0.006496 -0.005253       0.003438
# DL TP < 50 Kbps (%)                        0.197410  0.000604       0.001840
# 50 Kbps < DL TP < 250 Kbps (%)            -0.193948 -0.000515      -0.001656
# 250 Kbps < DL TP < 1 Mbps (%)             -0.145959 -0.000400      -0.001385
# DL TP > 1 Mbps (%)                        -0.103026 -0.000447      -0.001120
# UL TP < 10 Kbps (%)                        0.107199  0.001765       0.000820
# 10 Kbps < UL TP < 50 Kbps (%)             -0.082678 -0.001342      -0.000623
# 50 Kbps < UL TP < 300 Kbps (%)            -0.030623 -0.000616      -0.000236
# UL TP > 300 Kbps (%)                      -0.017919 -0.000482      -0.000158
# HTTP DL (Bytes)                            0.024795 -0.000709       0.020304
# HTTP UL (Bytes)                            0.038236 -0.000346       0.021468
# Activity Duration DL (ms)                 -0.072672 -0.000551      -0.001075
# Activity Duration UL (ms)                 -0.065697  0.000460      -0.001014
# Dur. (ms).1                                1.000000 -0.019798       0.024616
# Nb of sec with 125000B < Vol DL            0.067432 -0.000683       0.066178
# Nb of sec with 1250B < Vol UL < 6250B      0.042164 -0.000747       0.039928
# Nb of sec with 31250B < Vol DL < 125000B   0.073890  0.000989       0.068682
# Nb of sec with 37500B < Vol UL             0.012882 -0.003748       0.013035
# Nb of sec with 6250B < Vol DL < 31250B     0.072838 -0.006136       0.064048
# Nb of sec with 6250B < Vol UL < 37500B     0.014626 -0.002330       0.013566
# Nb of sec with Vol DL < 6250B             -0.059680  0.003790      -0.001315
# Nb of sec with Vol UL < 1250B             -0.065600  0.003328      -0.000902
# Social Media DL (Bytes)                   -0.002716  0.002759      -0.001859
# Social Media UL (Bytes)                   -0.001286 -0.004605       0.001290
# Google DL (Bytes)                          0.001228 -0.003120       0.000867
# Google UL (Bytes)                         -0.003466 -0.003454       0.002051
# Email DL (Bytes)                           0.003956 -0.001247       0.002759
# Email UL (Bytes)                          -0.001271 -0.003335       0.002628
# Youtube DL (Bytes)                         0.003853  0.000967       0.003344
# Youtube UL (Bytes)                         0.002211  0.002578       0.005482
# Netflix DL (Bytes)                        -0.001834 -0.003829       0.003370
# Netflix UL (Bytes)                        -0.005517  0.001217       0.000012
# Gaming DL (Bytes)                          0.000691  0.005149      -0.003618
# Gaming UL (Bytes)                          0.001841 -0.001209       0.003510
# Other DL (Bytes)                          -0.000404  0.000802      -0.001369
# Other UL (Bytes)                           0.001101 -0.001011       0.001324
# Total UL (Bytes)                          -0.001019  0.000744       0.005421
# Total DL (Bytes)                           0.000768  0.005030      -0.003415
#
#                                               IMEI  Avg RTT DL (ms)  \
# Bearer Id                                 0.164054        -0.022561
# Start ms                                 -0.001133         0.004141
# End ms                                   -0.000032        -0.005287
# Dur. (ms)                                -0.058043        -0.052472
# IMSI                                     -0.000536        -0.000365
# MSISDN/Number                             0.005703        -0.001701
# IMEI                                      1.000000        -0.003732
# Avg RTT DL (ms)                          -0.003732         1.000000
# Avg RTT UL (ms)                           0.134446         0.007867
# Avg Bearer TP DL (kbps)                   0.301312        -0.022698
# Avg Bearer TP UL (kbps)                   0.240492        -0.011409
# TCP DL Retrans. Vol (Bytes)               0.103018        -0.004757
# TCP UL Retrans. Vol (Bytes)               0.024287        -0.001843
# DL TP < 50 Kbps (%)                      -0.318413        -0.007646
# 50 Kbps < DL TP < 250 Kbps (%)            0.186724         0.014444
# 250 Kbps < DL TP < 1 Mbps (%)             0.279593         0.006010
# DL TP > 1 Mbps (%)                        0.308115        -0.006120
# UL TP < 10 Kbps (%)                      -0.198734         0.000866
# 10 Kbps < UL TP < 50 Kbps (%)             0.150153        -0.002933
# 50 Kbps < UL TP < 300 Kbps (%)            0.085759         0.001252
# UL TP > 300 Kbps (%)                      0.056228         0.000527
# HTTP DL (Bytes)                           0.114838        -0.002325
# HTTP UL (Bytes)                           0.149758        -0.005585
# Activity Duration DL (ms)                 0.406947         0.006999
# Activity Duration UL (ms)                 0.365607         0.005175
# Dur. (ms).1                              -0.058043        -0.052472
# Nb of sec with 125000B < Vol DL           0.323269         0.004092
# Nb of sec with 1250B < Vol UL < 6250B     0.166683        -0.002775
# Nb of sec with 31250B < Vol DL < 125000B  0.339418         0.011200
# Nb of sec with 37500B < Vol UL            0.083424         0.027255
# Nb of sec with 6250B < Vol DL < 31250B    0.320034        -0.000165
# Nb of sec with 6250B < Vol UL < 37500B    0.103696         0.011747
# Nb of sec with Vol DL < 6250B             0.488390         0.009447
# Nb of sec with Vol UL < 1250B             0.462545         0.009498
# Social Media DL (Bytes)                   0.000203         0.000843
# Social Media UL (Bytes)                  -0.005091        -0.001708
# Google DL (Bytes)                        -0.002073         0.001555
# Google UL (Bytes)                         0.005599         0.006130
# Email DL (Bytes)                         -0.003987        -0.004610
# Email UL (Bytes)                          0.003275        -0.004339
# Youtube DL (Bytes)                        0.001277        -0.000714
# Youtube UL (Bytes)                       -0.000728         0.004143
# Netflix DL (Bytes)                       -0.001591        -0.000945
# Netflix UL (Bytes)                       -0.004559        -0.006344
# Gaming DL (Bytes)                         0.001828        -0.003032
# Gaming UL (Bytes)                         0.003727        -0.009139
# Other DL (Bytes)                          0.004183        -0.000716
# Other UL (Bytes)                          0.000655         0.002466
# Total UL (Bytes)                         -0.000463        -0.003537
# Total DL (Bytes)                          0.001774        -0.003070
#
#                                           Avg RTT UL (ms)  \
# Bearer Id                                        0.034924
# Start ms                                        -0.002221
# End ms                                          -0.002607
# Dur. (ms)                                       -0.002981
# IMSI                                            -0.000437
# MSISDN/Number                                    0.008404
# IMEI                                             0.134446
# Avg RTT DL (ms)                                  0.007867
# Avg RTT UL (ms)                                  1.000000
# Avg Bearer TP DL (kbps)                          0.053914
# Avg Bearer TP UL (kbps)                          0.042500
# TCP DL Retrans. Vol (Bytes)                      0.025410
# TCP UL Retrans. Vol (Bytes)                      0.034791
# DL TP < 50 Kbps (%)                             -0.050171
# 50 Kbps < DL TP < 250 Kbps (%)                   0.025696
# 250 Kbps < DL TP < 1 Mbps (%)                    0.041394
# DL TP > 1 Mbps (%)                               0.051558
# UL TP < 10 Kbps (%)                             -0.062326
# 10 Kbps < UL TP < 50 Kbps (%)                    0.040633
# 50 Kbps < UL TP < 300 Kbps (%)                   0.042843
# UL TP > 300 Kbps (%)                             0.034036
# HTTP DL (Bytes)                                  0.024353
# HTTP UL (Bytes)                                  0.032386
# Activity Duration DL (ms)                        0.097627
# Activity Duration UL (ms)                        0.093357
# Dur. (ms).1                                     -0.002981
# Nb of sec with 125000B < Vol DL                  0.094915
# Nb of sec with 1250B < Vol UL < 6250B            0.112905
# Nb of sec with 31250B < Vol DL < 125000B         0.092809
# Nb of sec with 37500B < Vol UL                   0.147949
# Nb of sec with 6250B < Vol DL < 31250B           0.069953
# Nb of sec with 6250B < Vol UL < 37500B           0.170369
# Nb of sec with Vol DL < 6250B                    0.100919
# Nb of sec with Vol UL < 1250B                    0.090233
# Social Media DL (Bytes)                          0.000920
# Social Media UL (Bytes)                         -0.004725
# Google DL (Bytes)                               -0.000893
# Google UL (Bytes)                                0.002451
# Email DL (Bytes)                                 0.001071
# Email UL (Bytes)                                 0.000280
# Youtube DL (Bytes)                              -0.001698
# Youtube UL (Bytes)                               0.001591
# Netflix DL (Bytes)                              -0.000419
# Netflix UL (Bytes)                               0.000513
# Gaming DL (Bytes)                                0.002664
# Gaming UL (Bytes)                                0.002435
# Other DL (Bytes)                                 0.000094
# Other UL (Bytes)                                -0.001099
# Total UL (Bytes)                                 0.002009
# Total DL (Bytes)                                 0.002600
#
#                                           Avg Bearer TP DL (kbps)  ...  \
# Bearer Id                                                0.063973  ...
# Start ms                                                -0.000690  ...
# End ms                                                   0.000694  ...
# Dur. (ms)                                               -0.165355  ...
# IMSI                                                    -0.000557  ...
# MSISDN/Number                                           -0.001857  ...
# IMEI                                                     0.301312  ...
# Avg RTT DL (ms)                                         -0.022698  ...
# Avg RTT UL (ms)                                          0.053914  ...
# Avg Bearer TP DL (kbps)                                  1.000000  ...
# Avg Bearer TP UL (kbps)                                  0.557282  ...
# TCP DL Retrans. Vol (Bytes)                              0.097056  ...
# TCP UL Retrans. Vol (Bytes)                              0.015512  ...
# DL TP < 50 Kbps (%)                                     -0.603913  ...
# 50 Kbps < DL TP < 250 Kbps (%)                           0.475085  ...
# 250 Kbps < DL TP < 1 Mbps (%)                            0.447683  ...
# DL TP > 1 Mbps (%)                                       0.494771  ...
# UL TP < 10 Kbps (%)                                     -0.351390  ...
# 10 Kbps < UL TP < 50 Kbps (%)                            0.290595  ...
# 50 Kbps < UL TP < 300 Kbps (%)                           0.096628  ...
# UL TP > 300 Kbps (%)                                     0.073058  ...
# HTTP DL (Bytes)                                          0.113608  ...
# HTTP UL (Bytes)                                          0.118749  ...
# Activity Duration DL (ms)                                0.409502  ...
# Activity Duration UL (ms)                                0.384722  ...
# Dur. (ms).1                                             -0.165354  ...
# Nb of sec with 125000B < Vol DL                          0.198240  ...
# Nb of sec with 1250B < Vol UL < 6250B                    0.125864  ...
# Nb of sec with 31250B < Vol DL < 125000B                 0.144675  ...
# Nb of sec with 37500B < Vol UL                           0.024882  ...
# Nb of sec with 6250B < Vol DL < 31250B                   0.175842  ...
# Nb of sec with 6250B < Vol UL < 37500B                   0.035186  ...
# Nb of sec with Vol DL < 6250B                            0.435052  ...
# Nb of sec with Vol UL < 1250B                            0.452383  ...
# Social Media DL (Bytes)                                 -0.002177  ...
# Social Media UL (Bytes)                                 -0.000113  ...
# Google DL (Bytes)                                       -0.004009  ...
# Google UL (Bytes)                                       -0.000603  ...
# Email DL (Bytes)                                        -0.000425  ...
# Email UL (Bytes)                                         0.002145  ...
# Youtube DL (Bytes)                                       0.002418  ...
# Youtube UL (Bytes)                                      -0.003160  ...
# Netflix DL (Bytes)                                       0.005355  ...
# Netflix UL (Bytes)                                       0.003569  ...
# Gaming DL (Bytes)                                       -0.001315  ...
# Gaming UL (Bytes)                                        0.001864  ...
# Other DL (Bytes)                                         0.006849  ...
# Other UL (Bytes)                                         0.001652  ...
# Total UL (Bytes)                                         0.001712  ...
# Total DL (Bytes)                                        -0.001165  ...
#
#                                           Youtube DL (Bytes)  \
# Bearer Id                                          -0.002466
# Start ms                                           -0.001582
# End ms                                             -0.003741
# Dur. (ms)                                           0.003853
# IMSI                                                0.000967
# MSISDN/Number                                       0.003344
# IMEI                                                0.001277
# Avg RTT DL (ms)                                    -0.000714
# Avg RTT UL (ms)                                    -0.001698
# Avg Bearer TP DL (kbps)                             0.002418
# Avg Bearer TP UL (kbps)                             0.005618
# TCP DL Retrans. Vol (Bytes)                        -0.012370
# TCP UL Retrans. Vol (Bytes)                        -0.000694
# DL TP < 50 Kbps (%)                                -0.000788
# 50 Kbps < DL TP < 250 Kbps (%)                      0.002420
# 250 Kbps < DL TP < 1 Mbps (%)                      -0.000142
# DL TP > 1 Mbps (%)                                 -0.001467
# UL TP < 10 Kbps (%)                                -0.003474
# 10 Kbps < UL TP < 50 Kbps (%)                       0.003467
# 50 Kbps < UL TP < 300 Kbps (%)                      0.002606
# UL TP > 300 Kbps (%)                               -0.002169
# HTTP DL (Bytes)                                     0.001676
# HTTP UL (Bytes)                                     0.000909
# Activity Duration DL (ms)                           0.003020
# Activity Duration UL (ms)                           0.005030
# Dur. (ms).1                                         0.003853
# Nb of sec with 125000B < Vol DL                    -0.006235
# Nb of sec with 1250B < Vol UL < 6250B               0.003159
# Nb of sec with 31250B < Vol DL < 125000B           -0.004845
# Nb of sec with 37500B < Vol UL                     -0.006325
# Nb of sec with 6250B < Vol DL < 31250B              0.000388
# Nb of sec with 6250B < Vol UL < 37500B              0.000061
# Nb of sec with Vol DL < 6250B                       0.002571
# Nb of sec with Vol UL < 1250B                       0.001295
# Social Media DL (Bytes)                            -0.001389
# Social Media UL (Bytes)                            -0.001786
# Google DL (Bytes)                                   0.001760
# Google UL (Bytes)                                   0.001122
# Email DL (Bytes)                                    0.001679
# Email UL (Bytes)                                   -0.000320
# Youtube DL (Bytes)                                  1.000000
# Youtube UL (Bytes)                                  0.002433
# Netflix DL (Bytes)                                  0.001202
# Netflix UL (Bytes)                                  0.001746
# Gaming DL (Bytes)                                  -0.001861
# Gaming UL (Bytes)                                  -0.001893
# Other DL (Bytes)                                    0.002042
# Other UL (Bytes)                                   -0.004830
# Total UL (Bytes)                                   -0.000384
# Total DL (Bytes)                                    0.025685
#
#                                           Youtube UL (Bytes)  \
# Bearer Id                                          -0.000703
# Start ms                                            0.001238
# End ms                                             -0.003450
# Dur. (ms)                                           0.002211
# IMSI                                                0.002578
# MSISDN/Number                                       0.005482
# IMEI                                               -0.000728
# Avg RTT DL (ms)                                     0.004143
# Avg RTT UL (ms)                                     0.001591
# Avg Bearer TP DL (kbps)                            -0.003160
# Avg Bearer TP UL (kbps)                            -0.001406
# TCP DL Retrans. Vol (Bytes)                        -0.002500
# TCP UL Retrans. Vol (Bytes)                         0.001346
# DL TP < 50 Kbps (%)                                -0.000540
# 50 Kbps < DL TP < 250 Kbps (%)                     -0.000064
# 250 Kbps < DL TP < 1 Mbps (%)                      -0.000318
# DL TP > 1 Mbps (%)                                  0.002136
# UL TP < 10 Kbps (%)                                -0.001012
# 10 Kbps < UL TP < 50 Kbps (%)                       0.002933
# 50 Kbps < UL TP < 300 Kbps (%)                     -0.000624
# UL TP > 300 Kbps (%)                               -0.003198
# HTTP DL (Bytes)                                    -0.003539
# HTTP UL (Bytes)                                    -0.003893
# Activity Duration DL (ms)                           0.000283
# Activity Duration UL (ms)                           0.002466
# Dur. (ms).1                                         0.002211
# Nb of sec with 125000B < Vol DL                     0.003446
# Nb of sec with 1250B < Vol UL < 6250B              -0.005367
# Nb of sec with 31250B < Vol DL < 125000B            0.002882
# Nb of sec with 37500B < Vol UL                     -0.011961
# Nb of sec with 6250B < Vol DL < 31250B              0.003941
# Nb of sec with 6250B < Vol UL < 37500B             -0.006914
# Nb of sec with Vol DL < 6250B                       0.002756
# Nb of sec with Vol UL < 1250B                       0.004747
# Social Media DL (Bytes)                             0.002345
# Social Media UL (Bytes)                            -0.002368
# Google DL (Bytes)                                   0.000638
# Google UL (Bytes)                                   0.001670
# Email DL (Bytes)                                   -0.004305
# Email UL (Bytes)                                   -0.006834
# Youtube DL (Bytes)                                  0.002433
# Youtube UL (Bytes)                                  1.000000
# Netflix DL (Bytes)                                  0.000423
# Netflix UL (Bytes)                                  0.002477
# Gaming DL (Bytes)                                  -0.002382
# Gaming UL (Bytes)                                   0.000898
# Other DL (Bytes)                                    0.002296
# Other UL (Bytes)                                   -0.001393
# Total UL (Bytes)                                    0.563917
# Total DL (Bytes)                                   -0.002301
#
#                                           Netflix DL (Bytes)  \
# Bearer Id                                          -0.000622
# Start ms                                           -0.002593
# End ms                                              0.004132
# Dur. (ms)                                          -0.001834
# IMSI                                               -0.003829
# MSISDN/Number                                       0.003370
# IMEI                                               -0.001591
# Avg RTT DL (ms)                                    -0.000945
# Avg RTT UL (ms)                                    -0.000419
# Avg Bearer TP DL (kbps)                             0.005355
# Avg Bearer TP UL (kbps)                             0.006544
# TCP DL Retrans. Vol (Bytes)                        -0.003276
# TCP UL Retrans. Vol (Bytes)                         0.006576
# DL TP < 50 Kbps (%)                                -0.002733
# 50 Kbps < DL TP < 250 Kbps (%)                      0.004675
# 250 Kbps < DL TP < 1 Mbps (%)                       0.001812
# DL TP > 1 Mbps (%)                                 -0.001327
# UL TP < 10 Kbps (%)                                -0.005919
# 10 Kbps < UL TP < 50 Kbps (%)                       0.004973
# 50 Kbps < UL TP < 300 Kbps (%)                      0.002253
# UL TP > 300 Kbps (%)                                0.002977
# HTTP DL (Bytes)                                    -0.006088
# HTTP UL (Bytes)                                     0.001191
# Activity Duration DL (ms)                          -0.000915
# Activity Duration UL (ms)                           0.000532
# Dur. (ms).1                                        -0.001834
# Nb of sec with 125000B < Vol DL                    -0.001960
# Nb of sec with 1250B < Vol UL < 6250B               0.002306
# Nb of sec with 31250B < Vol DL < 125000B           -0.004603
# Nb of sec with 37500B < Vol UL                      0.008477
# Nb of sec with 6250B < Vol DL < 31250B             -0.003646
# Nb of sec with 6250B < Vol UL < 37500B              0.001776
# Nb of sec with Vol DL < 6250B                       0.001326
# Nb of sec with Vol UL < 1250B                       0.001235
# Social Media DL (Bytes)                            -0.001817
# Social Media UL (Bytes)                            -0.000772
# Google DL (Bytes)                                   0.000548
# Google UL (Bytes)                                  -0.001288
# Email DL (Bytes)                                    0.001351
# Email UL (Bytes)                                   -0.000011
# Youtube DL (Bytes)                                  0.001202
# Youtube UL (Bytes)                                  0.000423
# Netflix DL (Bytes)                                  1.000000
# Netflix UL (Bytes)                                  0.001065
# Gaming DL (Bytes)                                  -0.003201
# Gaming UL (Bytes)                                  -0.000633
# Other DL (Bytes)                                   -0.006000
# Other UL (Bytes)                                   -0.002588
# Total UL (Bytes)                                   -0.000662
# Total DL (Bytes)                                    0.024386
#
#                                           Netflix UL (Bytes)  \
# Bearer Id                                          -0.003725
# Start ms                                           -0.002334
# End ms                                             -0.001156
# Dur. (ms)                                          -0.005517
# IMSI                                                0.001217
# MSISDN/Number                                       0.000012
# IMEI                                               -0.004559
# Avg RTT DL (ms)                                    -0.006344
# Avg RTT UL (ms)                                     0.000513
# Avg Bearer TP DL (kbps)                             0.003569
# Avg Bearer TP UL (kbps)                             0.001366
# TCP DL Retrans. Vol (Bytes)                         0.002627
# TCP UL Retrans. Vol (Bytes)                        -0.004015
# DL TP < 50 Kbps (%)                                -0.003863
# 50 Kbps < DL TP < 250 Kbps (%)                      0.003564
# 250 Kbps < DL TP < 1 Mbps (%)                       0.003521
# DL TP > 1 Mbps (%)                                  0.002150
# UL TP < 10 Kbps (%)                                -0.003639
# 10 Kbps < UL TP < 50 Kbps (%)                       0.004682
# 50 Kbps < UL TP < 300 Kbps (%)                      0.002410
# UL TP > 300 Kbps (%)                               -0.002760
# HTTP DL (Bytes)                                    -0.007215
# HTTP UL (Bytes)                                     0.004277
# Activity Duration DL (ms)                          -0.001280
# Activity Duration UL (ms)                          -0.000018
# Dur. (ms).1                                        -0.005517
# Nb of sec with 125000B < Vol DL                    -0.002975
# Nb of sec with 1250B < Vol UL < 6250B               0.002548
# Nb of sec with 31250B < Vol DL < 125000B           -0.001537
# Nb of sec with 37500B < Vol UL                     -0.008910
# Nb of sec with 6250B < Vol DL < 31250B             -0.000361
# Nb of sec with 6250B < Vol UL < 37500B             -0.000376
# Nb of sec with Vol DL < 6250B                      -0.000095
# Nb of sec with Vol UL < 1250B                       0.000252
# Social Media DL (Bytes)                             0.003457
# Social Media UL (Bytes)                            -0.002493
# Google DL (Bytes)                                  -0.001569
# Google UL (Bytes)                                  -0.004073
# Email DL (Bytes)                                   -0.000016
# Email UL (Bytes)                                    0.000532
# Youtube DL (Bytes)                                  0.001746
# Youtube UL (Bytes)                                  0.002477
# Netflix DL (Bytes)                                  0.001065
# Netflix UL (Bytes)                                  1.000000
# Gaming DL (Bytes)                                  -0.001051
# Gaming UL (Bytes)                                  -0.004015
# Other DL (Bytes)                                   -0.006691
# Other UL (Bytes)                                   -0.003447
# Total UL (Bytes)                                    0.561779
# Total DL (Bytes)                                   -0.000979
#
#                                           Gaming DL (Bytes)  \
# Bearer Id                                          0.000487
# Start ms                                          -0.004229
# End ms                                            -0.004687
# Dur. (ms)                                          0.000691
# IMSI                                               0.005149
# MSISDN/Number                                     -0.003618
# IMEI                                               0.001828
# Avg RTT DL (ms)                                   -0.003032
# Avg RTT UL (ms)                                    0.002664
# Avg Bearer TP DL (kbps)                           -0.001315
# Avg Bearer TP UL (kbps)                           -0.000596
# TCP DL Retrans. Vol (Bytes)                       -0.003066
# TCP UL Retrans. Vol (Bytes)                       -0.003130
# DL TP < 50 Kbps (%)                               -0.000120
# 50 Kbps < DL TP < 250 Kbps (%)                     0.001474
# 250 Kbps < DL TP < 1 Mbps (%)                      0.000446
# DL TP > 1 Mbps (%)                                -0.001083
# UL TP < 10 Kbps (%)                                0.001153
# 10 Kbps < UL TP < 50 Kbps (%)                     -0.000479
# 50 Kbps < UL TP < 300 Kbps (%)                    -0.003108
# UL TP > 300 Kbps (%)                               0.002685
# HTTP DL (Bytes)                                   -0.006935
# HTTP UL (Bytes)                                   -0.005121
# Activity Duration DL (ms)                         -0.003634
# Activity Duration UL (ms)                         -0.002936
# Dur. (ms).1                                        0.000691
# Nb of sec with 125000B < Vol DL                   -0.003685
# Nb of sec with 1250B < Vol UL < 6250B             -0.003872
# Nb of sec with 31250B < Vol DL < 125000B          -0.002424
# Nb of sec with 37500B < Vol UL                     0.000539
# Nb of sec with 6250B < Vol DL < 31250B            -0.000110
# Nb of sec with 6250B < Vol UL < 37500B            -0.006642
# Nb of sec with Vol DL < 6250B                     -0.001008
# Nb of sec with Vol UL < 1250B                     -0.000713
# Social Media DL (Bytes)                            0.001018
# Social Media UL (Bytes)                            0.000210
# Google DL (Bytes)                                 -0.001421
# Google UL (Bytes)                                  0.001140
# Email DL (Bytes)                                   0.000050
# Email UL (Bytes)                                  -0.002519
# Youtube DL (Bytes)                                -0.001861
# Youtube UL (Bytes)                                -0.002382
# Netflix DL (Bytes)                                -0.003201
# Netflix UL (Bytes)                                -0.001051
# Gaming DL (Bytes)                                  1.000000
# Gaming UL (Bytes)                                  0.001162
# Other DL (Bytes)                                  -0.002591
# Other UL (Bytes)                                  -0.001131
# Total UL (Bytes)                                  -0.001858
# Total DL (Bytes)                                   0.999131
#
#                                           Gaming UL (Bytes)  Other DL (Bytes)  \
# Bearer Id                                         -0.003212          0.000943
# Start ms                                          -0.002512         -0.003687
# End ms                                             0.000988          0.002758
# Dur. (ms)                                          0.001841         -0.000404
# IMSI                                              -0.001209          0.000802
# MSISDN/Number                                      0.003510         -0.001369
# IMEI                                               0.003727          0.004183
# Avg RTT DL (ms)                                   -0.009139         -0.000716
# Avg RTT UL (ms)                                    0.002435          0.000094
# Avg Bearer TP DL (kbps)                            0.001864          0.006849
# Avg Bearer TP UL (kbps)                            0.000668          0.006815
# TCP DL Retrans. Vol (Bytes)                        0.008006          0.010351
# TCP UL Retrans. Vol (Bytes)                        0.003764         -0.005948
# DL TP < 50 Kbps (%)                               -0.000807         -0.005317
# 50 Kbps < DL TP < 250 Kbps (%)                    -0.000563          0.001875
# 250 Kbps < DL TP < 1 Mbps (%)                      0.001858          0.004924
# DL TP > 1 Mbps (%)                                 0.001076          0.007365
# UL TP < 10 Kbps (%)                                0.001442          0.000050
# 10 Kbps < UL TP < 50 Kbps (%)                     -0.001197         -0.000212
# 50 Kbps < UL TP < 300 Kbps (%)                    -0.002466         -0.000973
# UL TP > 300 Kbps (%)                              -0.000580         -0.000719
# HTTP DL (Bytes)                                    0.002934          0.008560
# HTTP UL (Bytes)                                   -0.002385          0.005377
# Activity Duration DL (ms)                          0.000112          0.008716
# Activity Duration UL (ms)                          0.000817          0.007874
# Dur. (ms).1                                        0.001841         -0.000404
# Nb of sec with 125000B < Vol DL                    0.000876          0.011310
# Nb of sec with 1250B < Vol UL < 6250B              0.001327          0.004197
# Nb of sec with 31250B < Vol DL < 125000B           0.001111          0.009018
# Nb of sec with 37500B < Vol UL                    -0.000313         -0.003043
# Nb of sec with 6250B < Vol DL < 31250B             0.003103          0.009239
# Nb of sec with 6250B < Vol UL < 37500B            -0.006837         -0.000428
# Nb of sec with Vol DL < 6250B                      0.002676          0.003190
# Nb of sec with Vol UL < 1250B                      0.002374          0.005356
# Social Media DL (Bytes)                            0.003095          0.006126
# Social Media UL (Bytes)                            0.000844         -0.003850
# Google DL (Bytes)                                 -0.001429         -0.002557
# Google UL (Bytes)                                 -0.002516          0.002097
# Email DL (Bytes)                                  -0.004335         -0.000444
# Email UL (Bytes)                                   0.005000         -0.003805
# Youtube DL (Bytes)                                -0.001893          0.002042
# Youtube UL (Bytes)                                 0.000898          0.002296
# Netflix DL (Bytes)                                -0.000633         -0.006000
# Netflix UL (Bytes)                                -0.004015         -0.006691
# Gaming DL (Bytes)                                  0.001162         -0.002591
# Gaming UL (Bytes)                                  1.000000         -0.002381
# Other DL (Bytes)                                  -0.002381          1.000000
# Other UL (Bytes)                                  -0.006011          0.003421
# Total UL (Bytes)                                   0.419690         -0.001921
# Total DL (Bytes)                                   0.001067         -0.002709
#
#                                           Other UL (Bytes)  Total UL (Bytes)  \
# Bearer Id                                        -0.002240         -0.004577
# Start ms                                          0.003803         -0.000028
# End ms                                            0.002786         -0.000574
# Dur. (ms)                                         0.001101         -0.001019
# IMSI                                             -0.001011          0.000744
# MSISDN/Number                                     0.001324          0.005421
# IMEI                                              0.000655         -0.000463
# Avg RTT DL (ms)                                   0.002466         -0.003537
# Avg RTT UL (ms)                                  -0.001099          0.002009
# Avg Bearer TP DL (kbps)                           0.001652          0.001712
# Avg Bearer TP UL (kbps)                          -0.000802          0.000151
# TCP DL Retrans. Vol (Bytes)                      -0.000841          0.003320
# TCP UL Retrans. Vol (Bytes)                      -0.004734         -0.001968
# DL TP < 50 Kbps (%)                               0.000887         -0.002308
# 50 Kbps < DL TP < 250 Kbps (%)                   -0.000592          0.001064
# 250 Kbps < DL TP < 1 Mbps (%)                    -0.003149          0.001309
# DL TP > 1 Mbps (%)                                0.001325          0.003489
# UL TP < 10 Kbps (%)                              -0.001880         -0.002934
# 10 Kbps < UL TP < 50 Kbps (%)                     0.004060          0.005600
# 50 Kbps < UL TP < 300 Kbps (%)                   -0.001086         -0.000455
# UL TP > 300 Kbps (%)                             -0.001966         -0.004391
# HTTP DL (Bytes)                                   0.001959         -0.003945
# HTTP UL (Bytes)                                   0.004454          0.001126
# Activity Duration DL (ms)                         0.001397          0.000119
# Activity Duration UL (ms)                         0.001899          0.002341
# Dur. (ms).1                                       0.001101         -0.001019
# Nb of sec with 125000B < Vol DL                   0.002322          0.001410
# Nb of sec with 1250B < Vol UL < 6250B             0.002045         -0.000480
# Nb of sec with 31250B < Vol DL < 125000B          0.000893          0.001678
# Nb of sec with 37500B < Vol UL                    0.005856         -0.009849
# Nb of sec with 6250B < Vol DL < 31250B           -0.001863          0.002055
# Nb of sec with 6250B < Vol UL < 37500B           -0.000620         -0.007869
# Nb of sec with Vol DL < 6250B                     0.002915          0.004128
# Nb of sec with Vol UL < 1250B                     0.002586          0.005060
# Social Media DL (Bytes)                           0.000610          0.004798
# Social Media UL (Bytes)                           0.000971         -0.000204
# Google DL (Bytes)                                -0.000882         -0.001492
# Google UL (Bytes)                                -0.002219          0.102113
# Email DL (Bytes)                                  0.004675         -0.002346
# Email UL (Bytes)                                  0.000081          0.022332
# Youtube DL (Bytes)                               -0.004830         -0.000384
# Youtube UL (Bytes)                               -0.001393          0.563917
# Netflix DL (Bytes)                               -0.002588         -0.000662
# Netflix UL (Bytes)                               -0.003447          0.561779
# Gaming DL (Bytes)                                -0.001131         -0.001858
# Gaming UL (Bytes)                                -0.006011          0.419690
# Other DL (Bytes)                                  0.003421         -0.001921
# Other UL (Bytes)                                  1.000000          0.417413
# Total UL (Bytes)                                  0.417413          1.000000
# Total DL (Bytes)                                 -0.001324         -0.001895
#
#                                           Total DL (Bytes)
# Bearer Id                                         0.000400
# Start ms                                         -0.004299
# End ms                                           -0.004687
# Dur. (ms)                                         0.000768
# IMSI                                              0.005030
# MSISDN/Number                                    -0.003415
# IMEI                                              0.001774
# Avg RTT DL (ms)                                  -0.003070
# Avg RTT UL (ms)                                   0.002600
# Avg Bearer TP DL (kbps)                          -0.001165
# Avg Bearer TP UL (kbps)                          -0.000265
# TCP DL Retrans. Vol (Bytes)                      -0.003508
# TCP UL Retrans. Vol (Bytes)                      -0.002977
# DL TP < 50 Kbps (%)                              -0.000156
# 50 Kbps < DL TP < 250 Kbps (%)                    0.001603
# 250 Kbps < DL TP < 1 Mbps (%)                     0.000461
# DL TP > 1 Mbps (%)                               -0.001209
# UL TP < 10 Kbps (%)                               0.000922
# 10 Kbps < UL TP < 50 Kbps (%)                    -0.000274
# 50 Kbps < UL TP < 300 Kbps (%)                   -0.002963
# UL TP > 300 Kbps (%)                              0.002681
# HTTP DL (Bytes)                                  -0.007058
# HTTP UL (Bytes)                                  -0.005068
# Activity Duration DL (ms)                        -0.003596
# Activity Duration UL (ms)                        -0.002780
# Dur. (ms).1                                       0.000768
# Nb of sec with 125000B < Vol DL                  -0.003965
# Nb of sec with 1250B < Vol UL < 6250B            -0.003669
# Nb of sec with 31250B < Vol DL < 125000B         -0.002652
# Nb of sec with 37500B < Vol UL                    0.000580
# Nb of sec with 6250B < Vol DL < 31250B           -0.000233
# Nb of sec with 6250B < Vol UL < 37500B           -0.006485
# Nb of sec with Vol DL < 6250B                    -0.000922
# Nb of sec with Vol UL < 1250B                    -0.000676
# Social Media DL (Bytes)                           0.005164
# Social Media UL (Bytes)                           0.000206
# Google DL (Bytes)                                 0.012189
# Google UL (Bytes)                                 0.001129
# Email DL (Bytes)                                  0.004395
# Email UL (Bytes)                                 -0.002516
# Youtube DL (Bytes)                                0.025685
# Youtube UL (Bytes)                               -0.002301
# Netflix DL (Bytes)                                0.024386
# Netflix UL (Bytes)                               -0.000979
# Gaming DL (Bytes)                                 0.999131
# Gaming UL (Bytes)                                 0.001067
# Other DL (Bytes)                                 -0.002709
# Other UL (Bytes)                                 -0.001324
# Total UL (Bytes)                                 -0.001895
# Total DL (Bytes)                                  1.000000
#
# [50 rows x 50 columns]

# %% [markdown]
# # Data Cleaning and Manipulation

# %%
# droping duplicate rows
preProcess.drop_duplicates()

# %%
#changing bytes to megabytes
preProcess.convertByteMB(['Total UL (Bytes)', 'Total DL (Bytes)', 'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)','Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)'])
# Out:
# Byte to MB change error
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN              NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1       1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2       1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3       1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4       1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082022e+14   3.365069e+10  3.548311e+13
# 149997    97970.0  2.082019e+14   3.366345e+10  3.566051e+13
# 149998    98249.0  2.082017e+14   3.362189e+10  3.572121e+13
# 149999    97910.0  2.082021e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#            Last Location Name  ...  Youtube DL (MegaBytes)  \
# 0       9.16456699548519E+015  ...            1.585461e+13
# 1                     L77566A  ...            2.024740e+13
# 2                     D42335A  ...            1.972566e+13
# 3                     T21824A  ...            2.138812e+13
# 4                     D88865A  ...            1.525938e+13
# ...                       ...  ...                     ...
# 149996                D20434A  ...            1.619167e+13
# 149997                D10223C  ...            1.387723e+13
# 149998                T51102A  ...            2.266051e+13
# 149999                L88342B  ...            8.817106e+12
# 150000                    NaN  ...            1.163407e+13
#
#         Youtube UL (MegaBytes)  Netflix DL (MegaBytes)  \
# 0                 2.501332e+12            8.198936e+12
# 1                 1.911173e+13            1.833841e+13
# 2                 1.469958e+13            1.758779e+13
# 3                 1.514664e+13            1.399465e+13
# 4                 1.896287e+13            1.712458e+13
# ...                        ...                     ...
# 149996            1.176343e+13            1.788370e+13
# 149997            8.288284e+12            1.935015e+13
# 149998            1.855903e+12            9.963942e+12
# 149999            8.305402e+12            3.322253e+12
# 150000            1.100941e+13            1.162685e+13
#
#         Netflix UL (MegaBytes)  Gaming DL (MegaBytes)  Gaming UL (MegaBytes)  \
# 0                 9.656251e+12           2.780823e+14           1.434415e+13
# 1                 1.722713e+13           6.087501e+14           1.170709e+12
# 2                 6.163408e+12           2.295846e+14           3.956300e+11
# 3                 1.097942e+12           7.995382e+14           1.084972e+13
# 4                 4.152180e+11           5.277072e+14           3.529801e+12
# ...                        ...                    ...                    ...
# 149996            1.967816e+13           5.266097e+14           9.197207e+12
# 149997            2.129315e+13           6.268931e+14           4.735033e+12
# 149998            5.065760e+12           5.535395e+14           1.339432e+13
# 149999            1.317259e+13           3.525370e+14           2.529475e+12
# 150000            1.100175e+13           4.220447e+14           8.288398e+12
#
#         Other DL (MegaBytes)  Other UL (MegaBytes)  Total UL (MegaBytes)  \
# 0               1.717444e+14          8.814393e+12          3.674974e+13
# 1               5.269042e+14          1.505514e+13          5.380039e+13
# 2               4.106926e+14          4.215763e+12          2.788364e+13
# 3               7.490399e+14          1.279728e+13          4.332422e+13
# 4               5.507095e+14          1.391032e+13          3.854281e+13
# ...                      ...                   ...                   ...
# 149996          3.264510e+12          1.348742e+13          5.762885e+13
# 149997          7.121804e+14          2.457758e+12          3.913508e+13
# 149998          1.211009e+14          1.131473e+13          3.491222e+13
# 149999          8.147131e+14          1.406930e+12          2.962610e+13
# 150000          4.211005e+14          8.264799e+12                   NaN
#
#         Total DL (MegaBytes)
# 0               3.088796e+14
# 1               6.533850e+14
# 2               2.798073e+14
# 3               8.460285e+14
# 4               5.691386e+14
# ...                      ...
# 149996          5.741753e+14
# 149997          6.666488e+14
# 149998          5.927864e+14
# 149999          3.718959e+14
# 150000                   NaN
#
# [150001 rows x 55 columns]

# %%
preProcess.colums_WithMissingValue()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
#  'Nb of sec with Vol DL < 6250B',
#  'Nb of sec with Vol UL < 1250B',
#  'Total UL (MegaBytes)',
#  'Total DL (MegaBytes)']

# %%
preProcess.get_column_based_missing_percentage()
# Out:
#                                           total_missing_values  \
# Bearer Id                                                  991
# Start                                                        1
# Start ms                                                     1
# End                                                          1
# End ms                                                       1
# Dur. (ms)                                                    1
# IMSI                                                       570
# MSISDN/Number                                             1066
# IMEI                                                       572
# Last Location Name                                        1153
# Avg RTT DL (ms)                                          27829
# Avg RTT UL (ms)                                          27812
# Avg Bearer TP DL (kbps)                                      1
# Avg Bearer TP UL (kbps)                                      1
# TCP DL Retrans. Vol (Bytes)                              88146
# TCP UL Retrans. Vol (Bytes)                              96649
# DL TP < 50 Kbps (%)                                        754
# 50 Kbps < DL TP < 250 Kbps (%)                             754
# 250 Kbps < DL TP < 1 Mbps (%)                              754
# DL TP > 1 Mbps (%)                                         754
# UL TP < 10 Kbps (%)                                        792
# 10 Kbps < UL TP < 50 Kbps (%)                              792
# 50 Kbps < UL TP < 300 Kbps (%)                             792
# UL TP > 300 Kbps (%)                                       792
# HTTP DL (Bytes)                                          81474
# HTTP UL (Bytes)                                          81810
# Activity Duration DL (ms)                                    1
# Activity Duration UL (ms)                                    1
# Dur. (ms).1                                                  1
# Handset Manufacturer                                       572
# Handset Type                                               572
# Nb of sec with 125000B < Vol DL                          97538
# Nb of sec with 1250B < Vol UL < 6250B                    92894
# Nb of sec with 31250B < Vol DL < 125000B                 93586
# Nb of sec with 37500B < Vol UL                          130254
# Nb of sec with 6250B < Vol DL < 31250B                   88317
# Nb of sec with 6250B < Vol UL < 37500B                  111843
# Nb of sec with Vol DL < 6250B                              755
# Nb of sec with Vol UL < 1250B                              793
# Social Media DL (MegaBytes)                                  0
# Social Media UL (MegaBytes)                                  0
# Google DL (MegaBytes)                                        0
# Google UL (MegaBytes)                                        0
# Email DL (MegaBytes)                                         0
# Email UL (MegaBytes)                                         0
# Youtube DL (MegaBytes)                                       0
# Youtube UL (MegaBytes)                                       0
# Netflix DL (MegaBytes)                                       0
# Netflix UL (MegaBytes)                                       0
# Gaming DL (MegaBytes)                                        0
# Gaming UL (MegaBytes)                                        0
# Other DL (MegaBytes)                                         0
# Other UL (MegaBytes)                                         0
# Total UL (MegaBytes)                                         1
# Total DL (MegaBytes)                                         1
#
#                                          missing_percentage
# Bearer Id                                            0.66 %
# Start                                                 0.0 %
# Start ms                                              0.0 %
# End                                                   0.0 %
# End ms                                                0.0 %
# Dur. (ms)                                             0.0 %
# IMSI                                                 0.38 %
# MSISDN/Number                                        0.71 %
# IMEI                                                 0.38 %
# Last Location Name                                   0.77 %
# Avg RTT DL (ms)                                     18.55 %
# Avg RTT UL (ms)                                     18.54 %
# Avg Bearer TP DL (kbps)                               0.0 %
# Avg Bearer TP UL (kbps)                               0.0 %
# TCP DL Retrans. Vol (Bytes)                         58.76 %
# TCP UL Retrans. Vol (Bytes)                         64.43 %
# DL TP < 50 Kbps (%)                                   0.5 %
# 50 Kbps < DL TP < 250 Kbps (%)                        0.5 %
# 250 Kbps < DL TP < 1 Mbps (%)                         0.5 %
# DL TP > 1 Mbps (%)                                    0.5 %
# UL TP < 10 Kbps (%)                                  0.53 %
# 10 Kbps < UL TP < 50 Kbps (%)                        0.53 %
# 50 Kbps < UL TP < 300 Kbps (%)                       0.53 %
# UL TP > 300 Kbps (%)                                 0.53 %
# HTTP DL (Bytes)                                     54.32 %
# HTTP UL (Bytes)                                     54.54 %
# Activity Duration DL (ms)                             0.0 %
# Activity Duration UL (ms)                             0.0 %
# Dur. (ms).1                                           0.0 %
# Handset Manufacturer                                 0.38 %
# Handset Type                                         0.38 %
# Nb of sec with 125000B < Vol DL                     65.02 %
# Nb of sec with 1250B < Vol UL < 6250B               61.93 %
# Nb of sec with 31250B < Vol DL < 125000B            62.39 %
# Nb of sec with 37500B < Vol UL                      86.84 %
# Nb of sec with 6250B < Vol DL < 31250B              58.88 %
# Nb of sec with 6250B < Vol UL < 37500B              74.56 %
# Nb of sec with Vol DL < 6250B                         0.5 %
# Nb of sec with Vol UL < 1250B                        0.53 %
# Social Media DL (MegaBytes)                           0.0 %
# Social Media UL (MegaBytes)                           0.0 %
# Google DL (MegaBytes)                                 0.0 %
# Google UL (MegaBytes)                                 0.0 %
# Email DL (MegaBytes)                                  0.0 %
# Email UL (MegaBytes)                                  0.0 %
# Youtube DL (MegaBytes)                                0.0 %
# Youtube UL (MegaBytes)                                0.0 %
# Netflix DL (MegaBytes)                                0.0 %
# Netflix UL (MegaBytes)                                0.0 %
# Gaming DL (MegaBytes)                                 0.0 %
# Gaming UL (MegaBytes)                                 0.0 %
# Other DL (MegaBytes)                                  0.0 %
# Other UL (MegaBytes)                                  0.0 %
# Total UL (MegaBytes)                                  0.0 %
# Total DL (MegaBytes)                                  0.0 %

# %% [markdown]
# # Droping colums that are >30% missing values

# %% [markdown]
# Filling missing values

# %%
data = df.ffill().bfill()

# %%
dataVal = data_preProcessing_script(data)

# %%
dataVal.get_column_based_missing_percentage()
# Out:
#                                           total_missing_values  \
# Bearer Id                                                    0
# Start                                                        0
# Start ms                                                     0
# End                                                          0
# End ms                                                       0
# Dur. (ms)                                                    0
# IMSI                                                         0
# MSISDN/Number                                                0
# IMEI                                                         0
# Last Location Name                                           0
# Avg RTT DL (ms)                                              0
# Avg RTT UL (ms)                                              0
# Avg Bearer TP DL (kbps)                                      0
# Avg Bearer TP UL (kbps)                                      0
# TCP DL Retrans. Vol (Bytes)                                  0
# TCP UL Retrans. Vol (Bytes)                                  0
# DL TP < 50 Kbps (%)                                          0
# 50 Kbps < DL TP < 250 Kbps (%)                               0
# 250 Kbps < DL TP < 1 Mbps (%)                                0
# DL TP > 1 Mbps (%)                                           0
# UL TP < 10 Kbps (%)                                          0
# 10 Kbps < UL TP < 50 Kbps (%)                                0
# 50 Kbps < UL TP < 300 Kbps (%)                               0
# UL TP > 300 Kbps (%)                                         0
# HTTP DL (Bytes)                                              0
# HTTP UL (Bytes)                                              0
# Activity Duration DL (ms)                                    0
# Activity Duration UL (ms)                                    0
# Dur. (ms).1                                                  0
# Handset Manufacturer                                         0
# Handset Type                                                 0
# Nb of sec with 125000B < Vol DL                              0
# Nb of sec with 1250B < Vol UL < 6250B                        0
# Nb of sec with 31250B < Vol DL < 125000B                     0
# Nb of sec with 37500B < Vol UL                               0
# Nb of sec with 6250B < Vol DL < 31250B                       0
# Nb of sec with 6250B < Vol UL < 37500B                       0
# Nb of sec with Vol DL < 6250B                                0
# Nb of sec with Vol UL < 1250B                                0
# Social Media DL (MegaBytes)                                  0
# Social Media UL (MegaBytes)                                  0
# Google DL (MegaBytes)                                        0
# Google UL (MegaBytes)                                        0
# Email DL (MegaBytes)                                         0
# Email UL (MegaBytes)                                         0
# Youtube DL (MegaBytes)                                       0
# Youtube UL (MegaBytes)                                       0
# Netflix DL (MegaBytes)                                       0
# Netflix UL (MegaBytes)                                       0
# Gaming DL (MegaBytes)                                        0
# Gaming UL (MegaBytes)                                        0
# Other DL (MegaBytes)                                         0
# Other UL (MegaBytes)                                         0
# Total UL (MegaBytes)                                         0
# Total DL (MegaBytes)                                         0
#
#                                          missing_percentage
# Bearer Id                                             0.0 %
# Start                                                 0.0 %
# Start ms                                              0.0 %
# End                                                   0.0 %
# End ms                                                0.0 %
# Dur. (ms)                                             0.0 %
# IMSI                                                  0.0 %
# MSISDN/Number                                         0.0 %
# IMEI                                                  0.0 %
# Last Location Name                                    0.0 %
# Avg RTT DL (ms)                                       0.0 %
# Avg RTT UL (ms)                                       0.0 %
# Avg Bearer TP DL (kbps)                               0.0 %
# Avg Bearer TP UL (kbps)                               0.0 %
# TCP DL Retrans. Vol (Bytes)                           0.0 %
# TCP UL Retrans. Vol (Bytes)                           0.0 %
# DL TP < 50 Kbps (%)                                   0.0 %
# 50 Kbps < DL TP < 250 Kbps (%)                        0.0 %
# 250 Kbps < DL TP < 1 Mbps (%)                         0.0 %
# DL TP > 1 Mbps (%)                                    0.0 %
# UL TP < 10 Kbps (%)                                   0.0 %
# 10 Kbps < UL TP < 50 Kbps (%)                         0.0 %
# 50 Kbps < UL TP < 300 Kbps (%)                        0.0 %
# UL TP > 300 Kbps (%)                                  0.0 %
# HTTP DL (Bytes)                                       0.0 %
# HTTP UL (Bytes)                                       0.0 %
# Activity Duration DL (ms)                             0.0 %
# Activity Duration UL (ms)                             0.0 %
# Dur. (ms).1                                           0.0 %
# Handset Manufacturer                                  0.0 %
# Handset Type                                          0.0 %
# Nb of sec with 125000B < Vol DL                       0.0 %
# Nb of sec with 1250B < Vol UL < 6250B                 0.0 %
# Nb of sec with 31250B < Vol DL < 125000B              0.0 %
# Nb of sec with 37500B < Vol UL                        0.0 %
# Nb of sec with 6250B < Vol DL < 31250B                0.0 %
# Nb of sec with 6250B < Vol UL < 37500B                0.0 %
# Nb of sec with Vol DL < 6250B                         0.0 %
# Nb of sec with Vol UL < 1250B                         0.0 %
# Social Media DL (MegaBytes)                           0.0 %
# Social Media UL (MegaBytes)                           0.0 %
# Google DL (MegaBytes)                                 0.0 %
# Google UL (MegaBytes)                                 0.0 %
# Email DL (MegaBytes)                                  0.0 %
# Email UL (MegaBytes)                                  0.0 %
# Youtube DL (MegaBytes)                                0.0 %
# Youtube UL (MegaBytes)                                0.0 %
# Netflix DL (MegaBytes)                                0.0 %
# Netflix UL (MegaBytes)                                0.0 %
# Gaming DL (MegaBytes)                                 0.0 %
# Gaming UL (MegaBytes)                                 0.0 %
# Other DL (MegaBytes)                                  0.0 %
# Other UL (MegaBytes)                                  0.0 %
# Total UL (MegaBytes)                                  0.0 %
# Total DL (MegaBytes)                                  0.0 %

# %%
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (MegaBytes)  Youtube UL (MegaBytes)  \
# 0  9.16456699548519E+015  ...            1.585461e+13            2.501332e+12
# 1                L77566A  ...            2.024740e+13            1.911173e+13
# 2                D42335A  ...            1.972566e+13            1.469958e+13
# 3                T21824A  ...            2.138812e+13            1.514664e+13
# 4                D88865A  ...            1.525938e+13            1.896287e+13
#
#    Netflix DL (MegaBytes)  Netflix UL (MegaBytes)  Gaming DL (MegaBytes)  \
# 0            8.198936e+12            9.656251e+12           2.780823e+14
# 1            1.833841e+13            1.722713e+13           6.087501e+14
# 2            1.758779e+13            6.163408e+12           2.295846e+14
# 3            1.399465e+13            1.097942e+12           7.995382e+14
# 4            1.712458e+13            4.152180e+11           5.277072e+14
#
#    Gaming UL (MegaBytes)  Other DL (MegaBytes)  Other UL (MegaBytes)  \
# 0           1.434415e+13          1.717444e+14          8.814393e+12
# 1           1.170709e+12          5.269042e+14          1.505514e+13
# 2           3.956300e+11          4.106926e+14          4.215763e+12
# 3           1.084972e+13          7.490399e+14          1.279728e+13
# 4           3.529801e+12          5.507095e+14          1.391032e+13
#
#    Total UL (MegaBytes)  Total DL (MegaBytes)
# 0          3.674974e+13          3.088796e+14
# 1          5.380039e+13          6.533850e+14
# 2          2.788364e+13          2.798073e+14
# 3          4.332422e+13          8.460285e+14
# 4          3.854281e+13          5.691386e+14
#
# [5 rows x 55 columns]

# %% [markdown]
# # Arrangeing the new df in xDR session

# %%
#getting the number od xDR sessions
df_new = (data.groupby(['MSISDN/Number'])['Bearer Id'].agg([('no.of xDR sessions','count')]).reset_index())

# %%
df_new.head()
# Out:
#    MSISDN/Number  no.of xDR sessions
# 0   3.360100e+10                   1
# 1   3.360100e+10                   1
# 2   3.360100e+10                   1
# 3   3.360101e+10                   1
# 4   3.360101e+10                   2

# %%
# Aggregation of Total values
df_new["Total Uploads"]=data["Google UL (MegaBytes)"]+data["Email UL (MegaBytes)"]+data["Social Media UL (MegaBytes)"]+data["Youtube UL (MegaBytes)"]+data["Netflix UL (MegaBytes)"]+data["Gaming UL (MegaBytes)"]+data["Other UL (MegaBytes)"]
df_new["Total Downloads"]=data["Google DL (MegaBytes)"]+data["Email DL (MegaBytes)"]+data["Social Media DL (MegaBytes)"]+data["Youtube DL (MegaBytes)"]+data["Netflix DL (MegaBytes)"]+data["Gaming DL (MegaBytes)"]+data["Other DL (MegaBytes)"]
df_new['Total UL and DL']=df_new['Total Downloads']+df_new["Total Uploads"]

# %%
# Aggregation of Total Social Media data
df_new["Youtube_Total_Data"]=data["Youtube DL (MegaBytes)"]+data["Youtube UL (MegaBytes)"]
df_new["Google_Total_Data"]=data["Google DL (MegaBytes)"]+data["Google UL (MegaBytes)"]
df_new["Email_Total_Data"]=data["Email DL (MegaBytes)"]+data["Email UL (MegaBytes)"]
df_new["Social_Media_Total_Data"]=data["Social Media DL (MegaBytes)"]+data["Social Media UL (MegaBytes)"]
df_new["Netflix_Total_Data"]=data["Netflix DL (MegaBytes)"]+data["Netflix UL (MegaBytes)"]
df_new["Gaming_Total_Data"]=data["Gaming DL (MegaBytes)"]+data["Gaming UL (MegaBytes)"]
df_new["Other_Total_Data"]=data["Other DL (MegaBytes)"]+data["Other UL (MegaBytes)"]

# %%
# Time aggregates
df_new['Start ms']=data['Start ms']
df_new['End ms']=data['End ms']
df_new['Start']=data['Start']
df_new['End']=data['End']
df_new['Avg Delay (ms)']=data['Avg RTT UL (ms)']+data['Avg RTT DL (ms)']
df_new['Dur. (ms)']=data['Dur. (ms)']
df_new['Dur. (ms).1']=data['Dur. (ms).1']
df_new["Activity_Duration(ms)"]=data['Activity Duration UL (ms)']+data['Activity Duration DL (ms)']

# %%
# total speed kbps
df_new['Avg Throughput (kbps)']=data['Avg Bearer TP UL (kbps)']+data['Avg Bearer TP DL (kbps)']

# %%
# categorical Variables
df_new['Handset Manufacturer']=data['Handset Manufacturer']
df_new['Handset Type']=data['Handset Type']
df_new['Last Location Name']=data['Last Location Name']
df_new['IMSI']=data['IMSI']
df_new['IMEI']=data['IMEI']

# %%
df_new.head()
# Out:
#    MSISDN/Number  no.of xDR sessions  Total Uploads  Total Downloads  \
# 0   3.360100e+10                   1   3.674974e+13     4.806241e+14
# 1   3.360100e+10                   1   5.380039e+13     1.180289e+15
# 2   3.360100e+10                   1   2.788364e+13     6.904999e+14
# 3   3.360101e+10                   1   4.332422e+13     1.595068e+15
# 4   3.360101e+10                   2   3.854281e+13     1.119848e+15
#
#    Total UL and DL  Youtube_Total_Data  Google_Total_Data  Email_Total_Data  \
# 0     5.173738e+14        1.835594e+13       2.905912e+12      3.701304e+12
# 1     1.234090e+15        3.935912e+13       4.414096e+12      9.373850e+11
# 2     7.183836e+14        3.442524e+13       1.022912e+13      3.363124e+12
# 3     1.638393e+15        3.653476e+13       1.181176e+13      2.070983e+12
# 4     1.158391e+15        3.422225e+13       7.748843e+12      2.110349e+12
#
#    Social_Media_Total_Data  Netflix_Total_Data  ...  Avg Delay (ms)  \
# 0             1.570185e+12        1.785519e+13  ...            47.0
# 1             1.933278e+12        3.556554e+13  ...            70.0
# 2             1.726277e+12        2.375120e+13  ...            70.0
# 3             6.574930e+11        1.509259e+13  ...            70.0
# 4             9.127880e+11        1.753980e+13  ...            70.0
#
#    Dur. (ms)   Dur. (ms).1  Activity_Duration(ms) Avg Throughput (kbps)  \
# 0  1823652.0  1.823653e+09                76411.0                  67.0
# 1  1365104.0  1.365104e+09                 3728.0                  42.0
# 2  1361762.0  1.361763e+09                    0.0                  15.0
# 3  1321509.0  1.321510e+09                41212.0                  88.0
# 4  1089009.0  1.089009e+09                    0.0                  15.0
#
#   Handset Manufacturer                 Handset Type     Last Location Name  \
# 0              Samsung   Samsung Galaxy A5 Sm-A520F  9.16456699548519E+015
# 1              Samsung  Samsung Galaxy J5 (Sm-J530)                L77566A
# 2              Samsung     Samsung Galaxy A8 (2018)                D42335A
# 3            undefined                    undefined                T21824A
# 4              Samsung             Samsung Sm-G390F                D88865A
#
#            IMSI          IMEI
# 0  2.082014e+14  3.552121e+13
# 1  2.082019e+14  3.579401e+13
# 2  2.082003e+14  3.528151e+13
# 3  2.082014e+14  3.535661e+13
# 4  2.082014e+14  3.540701e+13
#
# [5 rows x 26 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106856 entries, 0 to 106855
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MSISDN/Number            106856 non-null  float64
#  1   no.of xDR sessions       106856 non-null  int64
#  2   Total Uploads            106856 non-null  float64
#  3   Total Downloads          106856 non-null  float64
#  4   Total UL and DL          106856 non-null  float64
#  5   Youtube_Total_Data       106856 non-null  float64
#  6   Google_Total_Data        106856 non-null  float64
#  7   Email_Total_Data         106856 non-null  float64
#  8   Social_Media_Total_Data  106856 non-null  float64
#  9   Netflix_Total_Data       106856 non-null  float64
#  10  Gaming_Total_Data        106856 non-null  float64
#  11  Other_Total_Data         106856 non-null  float64
#  12  Start ms                 106856 non-null  float64
#  13  End ms                   106856 non-null  float64
#  14  Start                    106856 non-null  object
#  15  End                      106856 non-null  object
#  16  Avg Delay (ms)           106856 non-null  float64
#  17  Dur. (ms)                106856 non-null  float64
#  18  Dur. (ms).1              106856 non-null  float64
#  19  Activity_Duration(ms)    106856 non-null  float64
#  20  Avg Throughput (kbps)    106856 non-null  float64
#  21  Handset Manufacturer     106856 non-null  object
#  22  Handset Type             106856 non-null  object
#  23  Last Location Name       106856 non-null  object
#  24  IMSI                     106856 non-null  float64
#  25  IMEI                     106856 non-null  float64
# dtypes: float64(20), int64(1), object(5)
# memory usage: 21.2+ MB

# %% [markdown]
# # Produce clean data

# %%
print("""
# #######################################################
# produce clean data
# ########################################################
""")
df_new.to_csv('../data/cleaned_telecom_data.csv', index=False)
print('clean data successfully saved!!')
# Out:
# # #######################################################
# # produce clean data
# # ########################################################
#
# clean data successfully saved!!

# %% [markdown]
# cleaned data saved successfully
